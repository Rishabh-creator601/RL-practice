# %%
# !pip install stable_baselines3[extra]

# %%
import gym 
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import A2C
import numpy as np
import os

# %%
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unrar e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/

# %%
# TESTING 

env_name = 'Breakout-v0'
env = gym.make(env_name)

episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:4.0
# Episode:2 Score:1.0
# Episode:3 Score:5.0
# Episode:4 Score:0.0
# Episode:5 Score:1.0

# %%
#evaluating 

env = make_atari_env(env_name,n_envs=4,seed=0)  #TRAIN ON FOUR ENVS AND TEST ON ONE ENV 
env = VecFrameStack(env,n_stack=4)

# %%
model = A2C('CnnPolicy',env,verbose=1)
model.learn(total_timesteps=400000)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 262      |
# |    ep_rew_mean        | 1.25     |
# | time/                 |          |
# |    fps                | 121      |
# |    iterations         | 100      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.634   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0789  |
# |    value_loss         | 0.00971  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 274      |
# |    ep_rew_mean        | 1.44     |
# | time/                 |          |
# |    fps                | 122      |
# |    iterations         | 200      |
# ...

# %%
if not os.path.exists('Training/Models'):
  os.mkdir('Training')
  os.mkdir('Training/Models')

# %%
model_path  = os.path.join('Training','Models','A2C_MODEL')
model.save(model_path)

# %%
del model

# %%
env = make_atari_env(env_name,n_envs=1)
env = VecFrameStack(env,n_stack=4)

# %%
model = A2C.load(model_path,env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
evaluate_policy(model,env,n_eval_episodes=10)
# Out:
# (5.5, 2.3769728648009427)

# %%
#test again 
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = model.predict(obs)
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:[0.]
# Episode:2 Score:[1.]
# Episode:3 Score:[0.]
# Episode:4 Score:[0.]
# Episode:5 Score:[0.]
